# %% [markdown]
# # I CHOOSE KAGGLE + DATA SCIENCE.

# %% [markdown]
# ## ABOUT NOTEBOOK:-
# * After survey conducted by kaggle and I am as an enthusiat to learn Data Science, started thinking to do analysis on their dataset.
# * This thing encouraged me to make this notebook.
# * In this notebook I am analysing kaggle survey dataset by forming questions and then answering them.
# * The questions which I am analysing are given below:-
# #### Basic analysis:-
# * Q1). Ratio of gender in survey.
# * Q2). Ages of maximum of respondants.
# * Q3). Top 10 countries participating in survey.
# * Q4). Top 5 formal educations of respondants.
# * Q5). Top 10 Current Job Title.
# * Q6). Top 10 Industries of respondants.
# * Q7). Average years of experience of people who know about data science.
# * Q8). Current Yearly compensation of respondants.
# * Q9). Important Activities.
# ## Data Science Analysis:-
# * Q10). Current Employers incorporate Machine Learning or not.
# * Q11). Top 10 IDE.
# * Q12). Online Notebooks which are highly used people.
# *  Q13). Top 10 Programming Languages.
# *  Q14). Top 10 machine Learning libraries.
# * Q15). Top 10 Libraries for Visualization.
# * Q16). How long have people been writing code to analysis the data.
# * Q17). Top 10 Machine Learning products that are used at work.
# *

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, iplot, download_plotlyjs
import plotly.graph_objs as go
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
warnings.filterwarnings('ignore')

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['SurveySchema.csv', 'freeFormResponses.csv', 'multipleChoiceResponses.csv']

# %%
# Reading dataset in this form, so that I can use it on my laptop also.
try:
    df_mcr = pd.read_csv('../input/multipleChoiceResponses.csv')
    df_schema = pd.read_csv('../input/SurveySchema.csv')
except Exception as e:
    pass

# %%
# Basic information about Dataset.
print(df_mcr.shape)
print("As one can see there are 395 columns.")
# Out:
# (23860, 395)
# As one can see there are 395 columns.

# %%
# Let's see the details about the null values.
null = df_mcr.isnull().sum()
print(null[:30])
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q1_OTHER_TEXT                              0
# Q2                                         0
# Q3                                         0
# Q4                                       421
# Q5                                       912
# Q6                                       959
# Q6_OTHER_TEXT                              0
# Q7                                      2174
# Q7_OTHER_TEXT                              0
# Q8                                      2758
# Q9                                      3674
# Q10                                     3190
# Q11_Part_1                             14327
# Q11_Part_2                             18378
# Q11_Part_3                             18626
# Q11_Part_4                             16626
# Q11_Part_5                             18925
# Q11_Part_6                             20388
# Q11_Part_7                             22667
# Q11_OTHER_TEXT                             0
# Q12_MULTIPLE_CHOICE                     4661
# Q12_Part_1_TEXT                            0
# Q12_Part_2_TEXT                            0
# Q12_Part_3_TEXT                            0
# Q12_Part_4_TEXT                            0
# Q12_Part_5_TEXT                            0
# Q12_OTHER_TEXT                             0
# Q13_Part_1                              9849
# dtype: int64

# %% [markdown]
# * As one can see there are so many null values in columns but we do not have to remove them, as they  are
# * part of multiple choice questions.

# %%
df_mcr.head()
# Out:
#   Time from Start to Finish (seconds)                        ...                                                             Q50_OTHER_TEXT
# 0               Duration (in seconds)                        ...                          What barriers prevent you from making your wor...
# 1                                 710                        ...                                                                         -1
# 2                                 434                        ...                                                                         -1
# 3                                 718                        ...                                                                         -1
# 4                                 621                        ...                                                                         -1
#
# [5 rows x 395 columns]

# %% [markdown]
# # BASIC ANALYSIS

# %% [markdown]
# ### Q1). Ratio of gender in survey.

# %%
gender = df_mcr['Q1'].value_counts().reset_index()
gender.iplot(kind='pie', labels='index', values='Q1',title='Ration of Gender', pull=0.2, hole=0.2 )
# Out:
# <div>
#
#
#             <div id="ecba69cf-70bf-46aa-85d2-2aec37045cdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ecba69cf-70bf-46aa-85d2-2aec37045cdf")) {
#                     Plotly.newPlot(
#                         'ecba69cf-70bf-46aa-85d2-2aec37045cdf',
#                         [{"hole": 0.2, "labels": ["Male", "Female", "Prefer not to say", "Prefer to self-describe", "What is your gender? - Selected Choice"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "5a233e97-9d77-4d4a-809b-f70f13f85514", "values": [19430, 4010, 340, 79, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Ration of Gender"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ecba69cf-70bf-46aa-85d2-2aec37045cdf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * More than 80% of respondences are male.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q2). Ages of maximum of respondants.

# %%
age = df_mcr['Q2'].value_counts().reset_index()
age.iplot(kind='bar', x='index', y='Q2', title='Age of respondants', xTitle='Age',
          yTitle='Number of responses', colors='deepskyblue')
# Out:
# <div>
#
#
#             <div id="d8a328b4-220f-4706-b818-6c6623b5d733" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d8a328b4-220f-4706-b818-6c6623b5d733")) {
#                     Plotly.newPlot(
#                         'd8a328b4-220f-4706-b818-6c6623b5d733',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "Q2", "orientation": "v", "text": "", "type": "bar", "uid": "661de9a1-0821-4fd1-b6be-d51d8d54136a", "x": ["25-29", "22-24", "30-34", "18-21", "35-39", "40-44", "45-49", "50-54", "55-59", "60-69", "70-79", "80+", "What is your age (# years)?"], "y": [6159, 5141, 3776, 3037, 2253, 1360, 858, 582, 328, 273, 53, 39, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Age of respondants"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Age"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Number of responses"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d8a328b4-220f-4706-b818-6c6623b5d733');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Maximum number of people are in age group of 25 to 35.
# * As this is our demographic dividents.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q3). Top 10 countries participating in survey.

# %%
country = df_mcr['Q3'].value_counts().reset_index()[:10]
country.iplot(kind='bar', x='index', y='Q3', 
              title='Top 10 Countries participated in survey', xTitle='Country', yTitle='Number of Respondants')
country.drop([3], axis=0, inplace=True)
country
values = country['Q3'].values
#print(values)
name = country['index'].values
#print(name)
code = ['USA','IND','CHN','RUS','BRA','DEU','GBR','CAN','FRA']
data = dict(
        type = 'choropleth',
        locations = code,
        z = values,
        text = name,
        colorbar = {'title' : 'Number of Participants'},
      ) 
layout = dict(
    title = 'Country Wise Users',
    geo = dict(
        showframe = False,
        projection = {'type':'natural earth'}
    )
)
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="f8a548ca-e6b8-42b9-a815-7a93e373103d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f8a548ca-e6b8-42b9-a815-7a93e373103d")) {
#                     Plotly.newPlot(
#                         'f8a548ca-e6b8-42b9-a815-7a93e373103d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Q3", "orientation": "v", "text": "", "type": "bar", "uid": "2216deef-a5b9-464d-b561-7e218580b530", "x": ["United States of America", "India", "China", "Other", "Russia", "Brazil", "Germany", "United Kingdom of Great Britain and Northern Ireland", "France", "Canada"], "y": [4716, 4417, 1644, 1036, 879, 736, 734, 702, 604, 604]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Countries participated in survey"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Number of Respondants"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f8a548ca-e6b8-42b9-a815-7a93e373103d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="0e57678c-3426-46e3-9422-83904a2f0c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0e57678c-3426-46e3-9422-83904a2f0c29")) {
#                     Plotly.newPlot(
#                         '0e57678c-3426-46e3-9422-83904a2f0c29',
#                         [{"colorbar": {"title": {"text": "Number of Participants"}}, "locations": ["USA", "IND", "CHN", "RUS", "BRA", "DEU", "GBR", "CAN", "FRA"], "text": ["United States of America", "India", "China", "Russia", "Brazil", "Germany", "United Kingdom of Great Britain and Northern Ireland", "France", "Canada"], "type": "choropleth", "uid": "f8a7c1d2-6371-46bb-942b-c9ba659882e6", "z": [4716, 4417, 1644, 879, 736, 734, 702, 604, 604]}],
#                         {"geo": {"projection": {"type": "natural earth"}, "showframe": false}, "title": {"text": "Country Wise Users"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0e57678c-3426-46e3-9422-83904a2f0c29');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Maximum number of responses are from USA and India.
# * It indicates that maximum number of people who know Kaggle platforms are from USA and India.
# * Maximum number of people who are learning Data Science are from USA and India.
# * It's good to see India at this place.

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q4). Top 5 formal educations of respondants.

# %%
degree = df_mcr['Q4'].value_counts().reset_index()
degree.iplot(kind='bar',x='index', y='Q4', title='Top formal educations', xTitle='Degree', 
             yTitle='Frequency', colors='deepskyblue')
# Out:
# <div>
#
#
#             <div id="a372f8c6-57c9-4b5c-a84e-f437a8d3720e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a372f8c6-57c9-4b5c-a84e-f437a8d3720e")) {
#                     Plotly.newPlot(
#                         'a372f8c6-57c9-4b5c-a84e-f437a8d3720e',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "Q4", "orientation": "v", "text": "", "type": "bar", "uid": "c5d9e834-197a-4745-8f14-49ec4c861b2b", "x": ["Master\u2019s degree", "Bachelor\u2019s degree", "Doctoral degree", "Some college/university study without earning a bachelor\u2019s degree", "Professional degree", "I prefer not to answer", "No formal education past high school", "What is the highest level of formal education that you have attained or plan to attain within the next 2 years?"], "y": [10855, 7083, 3357, 967, 599, 345, 232, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top formal educations"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Degree"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a372f8c6-57c9-4b5c-a84e-f437a8d3720e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q5). Top 10 Current Job Title.

# %%
titles = df_mcr['Q6'].value_counts().reset_index()[:10]
titles.iplot(kind='bar',x='index', y='Q6', title='Top Current Titles', 
             xTitle='Title', yTitle='Frequency',colors='green')
# Out:
# <div>
#
#
#             <div id="7afabda9-e9b9-4f43-970c-1e8f5ba5dde1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7afabda9-e9b9-4f43-970c-1e8f5ba5dde1")) {
#                     Plotly.newPlot(
#                         '7afabda9-e9b9-4f43-970c-1e8f5ba5dde1',
#                         [{"marker": {"color": "rgba(0, 128, 0, 0.6)", "line": {"color": "rgba(0, 128, 0, 1.0)", "width": 1}}, "name": "Q6", "orientation": "v", "text": "", "type": "bar", "uid": "721eb3a1-65c7-4173-9484-a4da0da4744b", "x": ["Student", "Data Scientist", "Software Engineer", "Data Analyst", "Other", "Research Scientist", "Not employed", "Consultant", "Business Analyst", "Data Engineer"], "y": [5253, 4137, 3130, 1922, 1322, 1189, 842, 785, 772, 737]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top Current Titles"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Title"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7afabda9-e9b9-4f43-970c-1e8f5ba5dde1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### =================================================================================================

# %% [markdown]
# ### Q6). Top 10 Industries of respondants.

# %%
industry = df_mcr['Q7'].value_counts().reset_index()[:10]
industry.iplot(kind='bar',x='index', y='Q7', title='Top 10 Current industry', 
             xTitle='Industry', yTitle='Frequency',colors='indigo')
# Out:
# <div>
#
#
#             <div id="5994f146-fa7f-45b5-84f0-726090949c1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5994f146-fa7f-45b5-84f0-726090949c1e")) {
#                     Plotly.newPlot(
#                         '5994f146-fa7f-45b5-84f0-726090949c1e',
#                         [{"marker": {"color": "rgba(75, 0, 130, 0.6)", "line": {"color": "rgba(75, 0, 130, 1.0)", "width": 1}}, "name": "Q7", "orientation": "v", "text": "", "type": "bar", "uid": "5b585409-9278-408a-966c-a8d09472caf1", "x": ["Computers/Technology", "I am a student", "Academics/Education", "Accounting/Finance", "Other", "Online Service/Internet-based Services", "Medical/Pharmaceutical", "Government/Public Service", "Insurance/Risk Assessment", "Manufacturing/Fabrication"], "y": [5584, 4658, 2749, 1433, 940, 871, 751, 636, 564, 563]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Current industry"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Industry"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5994f146-fa7f-45b5-84f0-726090949c1e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Many respondants from students are also there.
# * Till now data science is widely used by computer, education, or finanace industries.
# * Government Sectors are far away from using data science, they should start to use data science otherwise they will lack behind from other Industries.****

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q7). Average years of experience of people who know about data science.

# %%
experience = df_mcr['Q8'].value_counts().reset_index()[:10]
experience.iplot(kind='bar',x='index', y='Q8', title='Average Years of experience', 
             xTitle='Years', yTitle='Frequency',colors='indianred')
# Out:
# <div>
#
#
#             <div id="a5f17ed4-251d-42e5-a7aa-70c86bc3a71d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a5f17ed4-251d-42e5-a7aa-70c86bc3a71d")) {
#                     Plotly.newPlot(
#                         'a5f17ed4-251d-42e5-a7aa-70c86bc3a71d',
#                         [{"marker": {"color": "rgba(205, 92, 92, 0.6)", "line": {"color": "rgba(205, 92, 92, 1.0)", "width": 1}}, "name": "Q8", "orientation": "v", "text": "", "type": "bar", "uid": "01daef53-dede-4e2f-ae7d-b3a76dee9344", "x": ["0-1", "1-2", "2-3", "5-10", "3-4", "10-15", "4-5", "15-20", "20-25", "30 +"], "y": [5898, 3745, 2577, 2524, 1751, 1512, 1488, 854, 384, 197]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Average Years of experience"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Years"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a5f17ed4-251d-42e5-a7aa-70c86bc3a71d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Maximum number of people are new in this field with experience of 1 to 3 years.
# * I think I choose data science at a correct time.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q8). Current Yearly compensation of respondants.

# %%
compensation = df_mcr['Q9'].value_counts().reset_index()[:10]
compensation.iplot(kind='bar',x='index', y='Q9', title='Average compensation', 
             xTitle='Amount of compensation', yTitle='Frequency',colors='indianred')
# Out:
# <div>
#
#
#             <div id="5b63ab7a-b43c-4ef7-a91b-92f7f4bf1b04" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5b63ab7a-b43c-4ef7-a91b-92f7f4bf1b04")) {
#                     Plotly.newPlot(
#                         '5b63ab7a-b43c-4ef7-a91b-92f7f4bf1b04',
#                         [{"marker": {"color": "rgba(205, 92, 92, 0.6)", "line": {"color": "rgba(205, 92, 92, 1.0)", "width": 1}}, "name": "Q9", "orientation": "v", "text": "", "type": "bar", "uid": "1b9bb406-29dd-465d-8e04-34ade9545509", "x": ["I do not wish to disclose my approximate yearly compensation", "0-10,000", "10-20,000", "20-30,000", "30-40,000", "40-50,000", "50-60,000", "100-125,000", "60-70,000", "70-80,000"], "y": [4756, 4398, 1937, 1395, 1119, 965, 919, 843, 729, 677]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Average compensation"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Amount of compensation"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5b63ab7a-b43c-4ef7-a91b-92f7f4bf1b04');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q9). Important Activities.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q11_Part_1'],temp_df.loc[:,'Q11_Part_2'],temp_df.loc[:,'Q11_Part_3'],
p4,p5  = temp_df.loc[:,'Q11_Part_4'],temp_df.loc[:,'Q11_Part_5'],
p6,p7 = temp_df.loc[:,'Q11_Part_6'],temp_df.loc[:,'Q11_Part_7']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7]).reset_index()      # Concating 7 columns of Q7.
new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()
new_df.columns = ['a','b']
new_df.iplot(kind='bar', x='a', y='b', title='Important Activities', xTitle='Activity', colors='brown')
# Out:
# <div>
#
#
#             <div id="cc97f5dd-13ce-40bd-87d3-4690a5515fde" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cc97f5dd-13ce-40bd-87d3-4690a5515fde")) {
#                     Plotly.newPlot(
#                         'cc97f5dd-13ce-40bd-87d3-4690a5515fde',
#                         [{"marker": {"color": "rgba(165, 42, 42, 0.6)", "line": {"color": "rgba(165, 42, 42, 1.0)", "width": 1}}, "name": "b", "orientation": "v", "text": "", "type": "bar", "uid": "1cd71b01-c673-4106-9128-72d068e803c2", "x": ["Analyze and understand data to influence product or business decisions", "Build prototypes to explore applying machine learning to new areas", "Build and/or run a machine learning service that operationally improves my product or workflows", "Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data", "Do research that advances the state of the art of machine learning", "None of these activities are an important part of my role at work", "Other"], "y": [9532, 7233, 5481, 5233, 4934, 3471, 1192]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Important Activities"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Activity"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('cc97f5dd-13ce-40bd-87d3-4690a5515fde');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # DATA SCIENCE ANALYSIS

# %% [markdown]
# ### Q10). Current Employers incorporate Machine Learning or not.

# %%
ml = df_mcr['Q10'].value_counts().reset_index()[:10]
ml.iplot(kind='bar',x='index', y='Q10', title='Use of ML ', 
             xTitle='Whether Ml is used or not', yTitle='Frequency',colors='indigo')
# Out:
# <div>
#
#
#             <div id="81305a9a-a801-431c-bf9e-62f3aeca5362" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81305a9a-a801-431c-bf9e-62f3aeca5362")) {
#                     Plotly.newPlot(
#                         '81305a9a-a801-431c-bf9e-62f3aeca5362',
#                         [{"marker": {"color": "rgba(75, 0, 130, 0.6)", "line": {"color": "rgba(75, 0, 130, 1.0)", "width": 1}}, "name": "Q10", "orientation": "v", "text": "", "type": "bar", "uid": "d1d3119a-074b-4e5b-9dc0-ab4132707389", "x": ["We are exploring ML methods (and may one day put a model into production)", "No (we do not use ML methods)", "We recently started using ML methods (i.e., models in production for less than 2 years)", "I do not know", "We have well established ML methods (i.e., models in production for more than 2 years)", "We use ML methods for generating insights (but do not put working models into production)", "Does your current employer incorporate machine learning methods into their business?"], "y": [4688, 4411, 3790, 2893, 2782, 2105, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Use of ML "}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Whether Ml is used or not"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frequency"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('81305a9a-a801-431c-bf9e-62f3aeca5362');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * ML is highly used in industries.
# * Maximum are exploring ML, means they are new to ML and they want to use ML.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q11). Top 10 IDE.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q13_Part_1'],temp_df.loc[:,'Q13_Part_2'],temp_df.loc[:,'Q13_Part_3'],
p4,p5  = temp_df.loc[:,'Q13_Part_4'],temp_df.loc[:,'Q13_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q13_Part_6'],temp_df.loc[:,'Q13_Part_7'],temp_df.loc[:,'Q13_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q13_Part_9'],temp_df.loc[:,'Q13_Part_10'],temp_df.loc[:,'Q13_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q13_Part_12'],temp_df.loc[:,'Q13_Part_13'],temp_df.loc[:,'Q13_Part_14']
p15 = temp_df.loc[:,'Q13_Part_15']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15]).reset_index()      # Concating 7 columns of Q7.
new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()
new_df.columns = ['a','b']
new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')
# Out:
# <div>
#
#
#             <div id="8cc232a2-9a09-4a7c-8183-d3c4988f4337" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8cc232a2-9a09-4a7c-8183-d3c4988f4337")) {
#                     Plotly.newPlot(
#                         '8cc232a2-9a09-4a7c-8183-d3c4988f4337',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "b", "orientation": "v", "text": "", "type": "bar", "uid": "92524432-656c-43c3-86e9-58aa81811deb", "x": ["Jupyter/IPython", "RStudio", "Notepad++", "PyCharm", "Sublime Text", "MATLAB", "Spyder", "Visual Studio", "Visual Studio Code", "Vim", "Atom", "IntelliJ", "Other", "None", "nteract"], "y": [14010, 8503, 7831, 7060, 5985, 5671, 5339, 5111, 5082, 4240, 3906, 3456, 1257, 474, 127]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "TOP IDE"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "IDE"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8cc232a2-9a09-4a7c-8183-d3c4988f4337');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Jupyter notebook is highly used by people follwed by RStudio.
# * Notebook++ is also in list.
# * PyCharm is mainly used backhand programmers.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q12). Online Notebooks which are highly used people.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q14_Part_1'],temp_df.loc[:,'Q14_Part_2'],temp_df.loc[:,'Q14_Part_3'],
p4,p5  = temp_df.loc[:,'Q14_Part_4'],temp_df.loc[:,'Q14_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q14_Part_6'],temp_df.loc[:,'Q14_Part_7'],temp_df.loc[:,'Q14_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q14_Part_9'],temp_df.loc[:,'Q14_Part_10'],temp_df.loc[:,'Q14_Part_11']
#p12,p13,p14 = temp_df.loc[:,'Q13_Part_12'],temp_df.loc[:,'Q13_Part_13'],temp_df.loc[:,'Q13_Part_14']
#p15 = temp_df.loc[:,'Q13_Part_15']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11]).reset_index()      # Concating 7 columns of Q7.
new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top ONLINE NOTEBOOKS', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="741d1e12-92d8-44d4-8940-247bb90dee61" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("741d1e12-92d8-44d4-8940-247bb90dee61")) {
#                     Plotly.newPlot(
#                         '741d1e12-92d8-44d4-8940-247bb90dee61',
#                         [{"hole": 0.2, "labels": ["None", "Kaggle Kernels", "JupyterHub/Binder", "Google Colab", "Google Cloud Datalab", "Azure Notebook", "Other", "Paperspace", "Floydhub", "Crestle", "Domino Datalab"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)", "rgba(128, 177, 211, 0.8999999999999999)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "7fbbd880-b8d4-4a13-941a-43b7d4c04548", "values": [7597, 6042, 4916, 3532, 1307, 1304, 690, 480, 361, 138, 119]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top ONLINE NOTEBOOKS"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('741d1e12-92d8-44d4-8940-247bb90dee61');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Kaggle kernels, they are highly used Data science people.
# * Followed by Jupyter Hub.
# * This is the reason I choose Kaggle + Data Science.
# * 28% people use no online notebook as they prefer to work on thier own machine.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q13). Top 10 Programming Languages.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q16_Part_1'],temp_df.loc[:,'Q16_Part_2'],temp_df.loc[:,'Q16_Part_3'],
p4,p5  = temp_df.loc[:,'Q16_Part_4'],temp_df.loc[:,'Q16_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q16_Part_6'],temp_df.loc[:,'Q16_Part_7'],temp_df.loc[:,'Q16_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q16_Part_9'],temp_df.loc[:,'Q16_Part_10'],temp_df.loc[:,'Q16_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q16_Part_12'],temp_df.loc[:,'Q16_Part_13'],temp_df.loc[:,'Q16_Part_14']
p15,p16,p17 = temp_df.loc[:,'Q16_Part_15'], temp_df.loc[:,'Q16_Part_16'], temp_df.loc[:,'Q16_Part_17']
p18 = temp_df.loc[:,'Q16_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Programming Languages', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="d500b5a6-c9a5-4dad-8274-41394d71f32e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d500b5a6-c9a5-4dad-8274-41394d71f32e")) {
#                     Plotly.newPlot(
#                         'd500b5a6-c9a5-4dad-8274-41394d71f32e',
#                         [{"hole": 0.2, "labels": ["Python", "SQL", "R", "C/C++", "Java", "Javascript/Typescript", "Bash", "MATLAB", "C#/.NET", "Visual Basic/VBA"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "fb25ce47-0ff7-4cc7-b260-9acd2cfd377f", "values": [15711, 8267, 6685, 4383, 3999, 3249, 2708, 2652, 1670, 1274]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Programming Languages"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d500b5a6-c9a5-4dad-8274-41394d71f32e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * As aspected python, sql and R at the top.
# * In future python will eat maximum languages.
# * 31% data science people use python.
# * SQL is also neccesary to connect with data base, which is at 16%.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q14). Top 10 machine Learning libraries.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q19_Part_1'],temp_df.loc[:,'Q19_Part_2'],temp_df.loc[:,'Q19_Part_3'],
p4,p5  = temp_df.loc[:,'Q19_Part_4'],temp_df.loc[:,'Q19_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q19_Part_6'],temp_df.loc[:,'Q19_Part_7'],temp_df.loc[:,'Q19_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q19_Part_9'],temp_df.loc[:,'Q19_Part_10'],temp_df.loc[:,'Q19_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q19_Part_12'],temp_df.loc[:,'Q19_Part_13'],temp_df.loc[:,'Q19_Part_14']
p15,p16,p17 = temp_df.loc[:,'Q19_Part_15'], temp_df.loc[:,'Q19_Part_16'], temp_df.loc[:,'Q19_Part_17']
p18 = temp_df.loc[:,'Q19_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Machine Learning Libraries', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="81b0b9af-abd7-4874-9646-bdc457b979bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81b0b9af-abd7-4874-9646-bdc457b979bd")) {
#                     Plotly.newPlot(
#                         '81b0b9af-abd7-4874-9646-bdc457b979bd',
#                         [{"hole": 0.2, "labels": ["Scikit-Learn", "TensorFlow", "Keras", "randomForest", "Xgboost", "PyTorch", "None", "Caret", "lightgbm", "Spark MLlib"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "77c5507b-513d-47b7-9897-ba4552028394", "values": [12249, 9981, 8136, 5967, 5571, 3826, 2918, 2220, 2099, 2055]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Machine Learning Libraries"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('81b0b9af-abd7-4874-9646-bdc457b979bd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### Observations:-
# * Scikit-learn topped the list followed by tensorflow and by keras.
# * 22% people use Scikit-learn.
# * 18% people use Tensorflow.
# * 14% people use Keras.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q15). Top 10 Libraries for Visualization.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q21_Part_1'],temp_df.loc[:,'Q21_Part_2'],temp_df.loc[:,'Q21_Part_3'],
p4,p5  = temp_df.loc[:,'Q21_Part_4'],temp_df.loc[:,'Q21_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q21_Part_6'],temp_df.loc[:,'Q21_Part_7'],temp_df.loc[:,'Q21_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q21_Part_9'],temp_df.loc[:,'Q21_Part_10'],temp_df.loc[:,'Q21_Part_11']
p12,p13 = temp_df.loc[:,'Q21_Part_12'],temp_df.loc[:,'Q21_Part_13']
#p15,p16,p17 = temp_df.loc[:,'Q16_Part_15'], temp_df.loc[:,'Q16_Part_16'], temp_df.loc[:,'Q16_Part_17']
#p18 = temp_df.loc[:,'Q16_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Libraries for Visualization', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="955dca4d-5d3b-4d09-9690-35db95675127" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("955dca4d-5d3b-4d09-9690-35db95675127")) {
#                     Plotly.newPlot(
#                         '955dca4d-5d3b-4d09-9690-35db95675127',
#                         [{"hole": 0.2, "labels": ["Matplotlib", "Seaborn", "ggplot2", "Plotly", "Shiny", "D3", "None", "Bokeh", "Leaflet", "Lattice"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "24d381aa-bd58-4dd3-bec3-373f65c6e18b", "values": [13392, 7775, 7751, 5597, 2628, 2219, 1921, 1907, 1013, 872]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Libraries for Visualization"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('955dca4d-5d3b-4d09-9690-35db95675127');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Matplotlib,the basic of visualization library, topped the list.
# * Seaborn,more advance than matplotlib and it is based on maplotlib, is at 2nd rank.
# * Plotly, which I am using right now, is at 4th place.
# * Feeling happy to see this list.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q16). How long have people been writing code to analysis the data.

# %%
time = df_mcr['Q24'].value_counts().reset_index()
time.iplot(kind='pie', labels='index', values='Q24',title='Time in Year ', pull=0.2, hole=0.2 )
# Out:
# <div>
#
#
#             <div id="ee6d345f-30ca-434c-a230-ccdc50cb690a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee6d345f-30ca-434c-a230-ccdc50cb690a")) {
#                     Plotly.newPlot(
#                         'ee6d345f-30ca-434c-a230-ccdc50cb690a',
#                         [{"hole": 0.2, "labels": ["1-2 years", "< 1 year", "3-5 years", "5-10 years", "10-20 years", "I have never written code but I want to learn", "20-30 years", "30-40 years", "40+ years", "I have never written code and I do not want to learn", "How long have you been writing code to analyze data?"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)", "rgba(128, 177, 211, 0.8999999999999999)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "9682fce6-7306-450d-b678-465924158b2d", "values": [5359, 4542, 4023, 2145, 1102, 821, 321, 117, 62, 41, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Time in Year "}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ee6d345f-30ca-434c-a230-ccdc50cb690a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Mainly people are using it for 1 to 5 year.
# * Totaly new field and expanding at a high pace.
# * Maybe my step to choose Data Science is correct, let's see in future.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q17). Top 10 Machine Learning products that are used at work.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q28_Part_1'],temp_df.loc[:,'Q28_Part_2'],temp_df.loc[:,'Q28_Part_3'],
p4,p5  = temp_df.loc[:,'Q28_Part_4'],temp_df.loc[:,'Q28_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q28_Part_6'],temp_df.loc[:,'Q28_Part_7'],temp_df.loc[:,'Q28_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q28_Part_9'],temp_df.loc[:,'Q28_Part_10'],temp_df.loc[:,'Q28_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q28_Part_12'],temp_df.loc[:,'Q28_Part_13'],temp_df.loc[:,'Q28_Part_14']
p15,p16,p17 = temp_df.loc[:,'Q28_Part_15'], temp_df.loc[:,'Q28_Part_16'], temp_df.loc[:,'Q28_Part_17']
p18 = temp_df.loc[:,'Q28_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Machine Learning Products', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="8cb7d1f3-a8a2-4660-9669-33911a2a36e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8cb7d1f3-a8a2-4660-9669-33911a2a36e5")) {
#                     Plotly.newPlot(
#                         '8cb7d1f3-a8a2-4660-9669-33911a2a36e5',
#                         [{"hole": 0.2, "labels": ["Google Cloud Machine Learning Engine", "Google Cloud Vision API", "Google Cloud Speech-to-text API", "Google Cloud Natural Language API", "Google Cloud Translation API", "Amazon SageMaker", "Google Cloud AutoML", "Amazon Rekognition", "H20 Driverless AI", "DataRobot"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "e6915628-9a0e-4d1a-becc-9f078b32edd0", "values": [665, 664, 624, 622, 530, 486, 432, 299, 283, 250]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Machine Learning Products"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8cb7d1f3-a8a2-4660-9669-33911a2a36e5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q18). Top 10 Big Data and Analytics Products.

# %%
df_mcr.loc[:, 'Q37_OTHER_TEXT':]
# Out:
#                                           Q37_OTHER_TEXT                        ...                                                             Q50_OTHER_TEXT
# 0      On which online platform have you spent the mo...                        ...                          What barriers prevent you from making your wor...
# 1                                                     -1                        ...                                                                         -1
# 2                                                     -1                        ...                                                                         -1
# 3                                                     -1                        ...                                                                         -1
# 4                                                     -1                        ...                                                                         -1
# 5                                                     -1                        ...                                                                         -1
# 6                                                     -1                        ...                                                                         -1
# 7                                                     -1                        ...                                                                         -1
# 8                                                     -1                        ...                                                                         -1
# 9                                                     -1                        ...                                                                         -1
# 10                                                    -1                        ...                                                                         -1
# 11                                                    -1                        ...                                                                         -1
# 12                                                    -1                        ...                                                                         -1
# 13                                                     0                        ...                                                                         -1
# 14                                                    -1                        ...                                                                         -1
# 15                                                    -1                        ...                                                                         -1
# 16                                                    -1                        ...                                                                         -1
# 17                                                    -1                        ...                                                                         -1
# 18                                                    -1                        ...                                                                         -1
# 19                                                    -1                        ...                                                                         -1
# 20                                                    -1                        ...                                                                         -1
# 21                                                    -1                        ...                                                                         -1
# 22                                                    -1                        ...                                                                         -1
# 23                                                    -1                        ...                                                                         -1
# 24                                                    -1                        ...                                                                         -1
# 25                                                    -1                        ...                                                                         -1
# 26                                                    -1                        ...                                                                         -1
# 27                                                    -1                        ...                                                                         -1
# 28                                                    -1                        ...                                                                         -1
# 29                                                    -1                        ...                                                                         -1
# ...                                                  ...                        ...                                                                        ...
# 23830                                                 -1                        ...                                                                         -1
# 23831                                                 -1                        ...                                                                         -1
# 23832                                                 -1                        ...                                                                         -1
# 23833                                                 -1                        ...                                                                         -1
# 23834                                                 -1                        ...                                                                         -1
# 23835                                                 -1                        ...                                                                         -1
# 23836                                                 -1                        ...                                                                         -1
# 23837                                                 -1                        ...                                                                         -1
# 23838                                                 -1                        ...                                                                         -1
# 23839                                                 -1                        ...                                                                         -1
# 23840                                                 -1                        ...                                                                         -1
# 23841                                                 -1                        ...                                                                         -1
# 23842                                                 -1                        ...                                                                         -1
# 23843                                                 -1                        ...                                                                         -1
# 23844                                                 -1                        ...                                                                         -1
# 23845                                                 -1                        ...                                                                         -1
# 23846                                                 -1                        ...                                                                         -1
# 23847                                                 -1                        ...                                                                         -1
# 23848                                                 -1                        ...                                                                         -1
# 23849                                                 -1                        ...                                                                         -1
# 23850                                                 -1                        ...                                                                         -1
# 23851                                                 -1                        ...                                                                         -1
# 23852                                                 -1                        ...                                                                         -1
# 23853                                                 -1                        ...                                                                         -1
# 23854                                                 -1                        ...                                                                         -1
# 23855                                                 -1                        ...                                                                         -1
# 23856                                                 -1                        ...                                                                         -1
# 23857                                                 -1                        ...                                                                         -1
# 23858                                                 -1                        ...                                                                         -1
# 23859                                                 -1                        ...                                                                         -1
#
# [23860 rows x 89 columns]

# %%
df_mcr.loc[0,'Q39_Part_1']
# Out:
# 'How do you perceive the quality of online learning platforms and in-person bootcamps as compared to the quality of the education provided by traditional brick and mortar institutions? - Online learning platforms and MOOCs:'

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q30_Part_1'],temp_df.loc[:,'Q30_Part_2'],temp_df.loc[:,'Q30_Part_3'],
p4,p5  = temp_df.loc[:,'Q30_Part_4'],temp_df.loc[:,'Q30_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q30_Part_6'],temp_df.loc[:,'Q30_Part_7'],temp_df.loc[:,'Q30_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q30_Part_9'],temp_df.loc[:,'Q30_Part_10'],temp_df.loc[:,'Q30_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q30_Part_12'],temp_df.loc[:,'Q30_Part_13'],temp_df.loc[:,'Q30_Part_14']
p15,p16,p17 = temp_df.loc[:,'Q30_Part_15'], temp_df.loc[:,'Q30_Part_16'], temp_df.loc[:,'Q30_Part_17']
p18 = temp_df.loc[:,'Q30_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Big Data and Analytic Products', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="a3811046-ed8a-44e1-a860-0d2e0539fcd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a3811046-ed8a-44e1-a860-0d2e0539fcd3")) {
#                     Plotly.newPlot(
#                         'a3811046-ed8a-44e1-a860-0d2e0539fcd3',
#                         [{"hole": 0.2, "labels": ["Google BigQuery", "AWS Redshift", "Databricks", "AWS Elastic MapReduce", "Teradata", "Microsoft Analysis Services", "Google Cloud Dataflow", "AWS Athena", "AWS Kinesis", "Google Cloud Pub/Sub"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "d96fb6ae-4065-4305-92b7-7643baf34c86", "values": [1205, 942, 831, 621, 597, 421, 385, 383, 334, 286]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Big Data and Analytic Products"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a3811046-ed8a-44e1-a860-0d2e0539fcd3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ================================================================================================

# %% [markdown]
# ### Q19). Top 10 types of Data people currently interact.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q31_Part_1'],temp_df.loc[:,'Q31_Part_2'],temp_df.loc[:,'Q31_Part_3'],
p4,p5  = temp_df.loc[:,'Q31_Part_4'],temp_df.loc[:,'Q31_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q31_Part_6'],temp_df.loc[:,'Q31_Part_7'],temp_df.loc[:,'Q31_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q31_Part_9'],temp_df.loc[:,'Q31_Part_10'],temp_df.loc[:,'Q31_Part_11']
p12 = temp_df.loc[:,'Q31_Part_12']
#p15,p16,p17 = temp_df.loc[:,'Q30_Part_15'], temp_df.loc[:,'Q30_Part_16'], temp_df.loc[:,'Q30_Part_17']
#p18 = temp_df.loc[:,'Q30_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Type of Data', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="7d4715f9-257f-4b75-9c18-483dd4a4d237" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7d4715f9-257f-4b75-9c18-483dd4a4d237")) {
#                     Plotly.newPlot(
#                         '7d4715f9-257f-4b75-9c18-483dd4a4d237',
#                         [{"hole": 0.2, "labels": ["Numerical Data", "Text Data", "Categorical Data", "Time Series Data", "Tabular Data", "Image Data", "Sensor Data", "Geospatial Data", "Video Data", "Genetic Data"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "dd950afe-bcd4-4f1b-8eae-7c8f234b13fd", "values": [11024, 8729, 8149, 7779, 7394, 5387, 2552, 2245, 1383, 1054]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Type of Data"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7d4715f9-257f-4b75-9c18-483dd4a4d237');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Mainly people interact with numerical data then by text data and then by categorical data.
# * So practice on these type of data will help.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q20). Top 10 places to find Pubic Datasets.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q33_Part_1'],temp_df.loc[:,'Q33_Part_2'],temp_df.loc[:,'Q33_Part_3'],
p4,p5  = temp_df.loc[:,'Q33_Part_4'],temp_df.loc[:,'Q33_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q33_Part_6'],temp_df.loc[:,'Q33_Part_7'],temp_df.loc[:,'Q33_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q33_Part_9'],temp_df.loc[:,'Q33_Part_10'],temp_df.loc[:,'Q33_Part_11']
#p12 = temp_df.loc[:,'Q31_Part_12']
#p15,p16,p17 = temp_df.loc[:,'Q30_Part_15'], temp_df.loc[:,'Q30_Part_16'], temp_df.loc[:,'Q30_Part_17']
#p18 = temp_df.loc[:,'Q30_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
new_df.iplot(kind='bar', x='a', y='b', title='TOP Places for Dataset', xTitle='Place', colors='deepskyblue')    
#new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Type of Data', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="4ad76557-2aa4-4d9b-b35b-3b8202592382" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4ad76557-2aa4-4d9b-b35b-3b8202592382")) {
#                     Plotly.newPlot(
#                         '4ad76557-2aa4-4d9b-b35b-3b8202592382',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "b", "orientation": "v", "text": "", "type": "bar", "uid": "781032be-9465-42d8-847c-e202c4517211", "x": ["Dataset aggregator/platform (Socrata, Kaggle Public Datasets Platform, etc.)", "Google Search", "GitHub", "I collect my own data (web-scraping, etc.)", "Government websites", "University research group websites", "Google Dataset Search", "Publicly released data from private companies", "Non-profit research group websites", "None/I do not work with public data"], "y": [8175, 7013, 6075, 5225, 4757, 4103, 3684, 2997, 2808, 2027]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "TOP Places for Dataset"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Place"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4ad76557-2aa4-4d9b-b35b-3b8202592382');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Maximum people get their dataset from kaggle.
# * As expected kaggle lead the race.
# * The reason I choose kaggle.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q21). Top 10  Online Platforms to learn Data Science.

# %%
online = df_mcr['Q37'].value_counts().reset_index()[:10]
online.iplot(kind='pie', labels='index', values='Q37',title='Top 10 Online Platforms to learn Data Science ',
             pull=0.2, hole=0.2 )
# Out:
# <div>
#
#
#             <div id="9d24d154-410a-4ae9-abf6-909c8c8711b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9d24d154-410a-4ae9-abf6-909c8c8711b8")) {
#                     Plotly.newPlot(
#                         '9d24d154-410a-4ae9-abf6-909c8c8711b8',
#                         [{"hole": 0.2, "labels": ["Coursera", "DataCamp", "Udemy", "Udacity", "edX", "Kaggle Learn", "Online University Courses", "Other", "Fast.AI", "developers.google.com"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "a53ca950-25ab-4939-a5d4-b7b2fbf2c147", "values": [3748, 1166, 1146, 816, 778, 663, 502, 337, 266, 117]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Online Platforms to learn Data Science "}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9d24d154-410a-4ae9-abf6-909c8c8711b8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * 40% people are learning from Coursera.
# * Datacamp, udemy are at 2nd and 3rd places with 12% each.
# * Mainly people are learning Data Science from online courses.
# * Online courses are very flexible, so they are in high demnad.

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q22). Top 10 Websites for Data Science News.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2,p3 = temp_df.loc[:,'Q38_Part_1'],temp_df.loc[:,'Q38_Part_2'],temp_df.loc[:,'Q38_Part_3'],
p4,p5  = temp_df.loc[:,'Q38_Part_4'],temp_df.loc[:,'Q38_Part_5'],
p6,p7,p8 = temp_df.loc[:,'Q38_Part_6'],temp_df.loc[:,'Q38_Part_7'],temp_df.loc[:,'Q38_Part_8']
p9,p10,p11 = temp_df.loc[:,'Q38_Part_9'],temp_df.loc[:,'Q38_Part_10'],temp_df.loc[:,'Q38_Part_11']
p12,p13,p14 = temp_df.loc[:,'Q38_Part_12'],temp_df.loc[:,'Q38_Part_13'],temp_df.loc[:,'Q38_Part_14']
p15,p16,p17 = temp_df.loc[:,'Q38_Part_15'], temp_df.loc[:,'Q38_Part_16'], temp_df.loc[:,'Q38_Part_17']
p18 = temp_df.loc[:,'Q38_Part_18']

new_df = pd.concat([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13,p14,p15,p16,p17,p18]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='Top 10 Websites for Data Science News', pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="d3f7f450-3c30-4879-9904-56b29bf8d8e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d3f7f450-3c30-4879-9904-56b29bf8d8e5")) {
#                     Plotly.newPlot(
#                         'd3f7f450-3c30-4879-9904-56b29bf8d8e5',
#                         [{"hole": 0.2, "labels": ["Kaggle forums", "Medium Blog Posts", "ArXiv & Preprints", "Twitter", "r/machinelearning", "KDnuggets Blog", "Journal Publications", "Siraj Raval YouTube Channel", "Hacker News", "FiveThirtyEight.com"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "2fca4d17-37d5-4cf9-8f01-db57effa4e4a", "values": [5563, 5011, 3142, 3138, 3059, 3050, 2149, 2024, 2012, 1543]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Websites for Data Science News"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d3f7f450-3c30-4879-9904-56b29bf8d8e5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * Kaggleform is at top place with 18%.
# * It is followed by mediumblog post.
# * Kaggle is again at the top.
# * Many things I am learning from kaggle platform.

# %% [markdown]
#  ### Q23). People view on the quality of Online learning and  bootcamp.

# %%
temp_df = df_mcr.drop([0],axis=0)
temp_df.head()

p1,p2 = temp_df.loc[:,'Q39_Part_1'],temp_df.loc[:,'Q39_Part_2']


new_df = pd.concat([p1,p2]).reset_index()      

new_df.dropna(inplace=True)
new_df = new_df[0].value_counts().reset_index()[:10]
new_df.columns = ['a','b']
#new_df.iplot(kind='bar', x='a', y='b', title='TOP IDE', xTitle='IDE', colors='deepskyblue')    
new_df.iplot(kind='pie', labels='a', values='b', title='View on quality of OnlineLearning and Bootcamp',
             pull=0.2, hole=0.2)
# Out:
# <div>
#
#
#             <div id="504d3678-fd72-4682-8344-b46bb58e892b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("504d3678-fd72-4682-8344-b46bb58e892b")) {
#                     Plotly.newPlot(
#                         '504d3678-fd72-4682-8344-b46bb58e892b',
#                         [{"hole": 0.2, "labels": ["Slightly better", "No opinion; I do not know", "Much better", "Neither better nor worse", "Slightly worse", "Much worse"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "54eff9d8-7594-4d26-821b-f15b7aa323c0", "values": [8079, 6877, 6689, 6658, 2731, 924]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "View on quality of OnlineLearning and Bootcamp"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('504d3678-fd72-4682-8344-b46bb58e892b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Observations:-
# * 50% people love to learn from online sources or from bootcamp.
# * This is a new type of education revolution.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q24). Academic Achievement VS Independent projects for Data Science.

# %%
online = df_mcr['Q40'].value_counts().reset_index()[:10]
online.iplot(kind='bar', x='index', y='Q40',title='Academic Achievement VS Independent projects for Data Science ',
             xTitle='Comparision', colors='deepskyblue' )
# Out:
# <div>
#
#
#             <div id="eecfbfe9-8368-4723-9f5b-3e944369fdc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eecfbfe9-8368-4723-9f5b-3e944369fdc7")) {
#                     Plotly.newPlot(
#                         'eecfbfe9-8368-4723-9f5b-3e944369fdc7',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "Q40", "orientation": "v", "text": "", "type": "bar", "uid": "95f8461d-191d-4de1-878c-0b423126d82b", "x": ["Independent projects are much more important than academic achievements", "Independent projects are slightly more important than academic achievements", "Independent projects are equally important as academic achievements", "No opinion; I do not know", "Independent projects are slightly less important than academic achievements", "Independent projects are much less important than academic achievements", "Which better demonstrates expertise in data science: academic achievements or independent projects? - Your views:"], "y": [4990, 4473, 4343, 936, 831, 306, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Academic Achievement VS Independent projects for Data Science "}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Comparision"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('eecfbfe9-8368-4723-9f5b-3e944369fdc7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Independent projects are more important than academic achievement.

# %% [markdown]
# #### ===================================================================================================
# #### ===================================================================================================
# #### ===================================================================================================
